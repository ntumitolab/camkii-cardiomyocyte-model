# %% [markdown]
# # Runtime information

# %%
using InteractiveUtils
InteractiveUtils.versioninfo()
# Out:
# Julia Version 1.11.4
# Commit 8561cc3d68d (2025-03-10 11:36 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 12 × Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz
#   WORD_SIZE: 64
#   LLVM: libLLVM-16.0.6 (ORCJIT, skylake)
# Threads: 2 default, 0 interactive, 1 GC (on 12 virtual cores)
# Environment:
#   LD_LIBRARY_PATH = /home/github/actions-runner-1/_work/_tool/Python/3.13.2/x64/lib
#   JULIA_PROJECT = /home/github/actions-runner-1/_work/camkii-cardiomyocyte-model/camkii-cardiomyocyte-model/Project.toml
#   JULIA_CONDAPKG_BACKEND = Null
#   JULIA_NUM_THREADS = 2
#   JULIA_CI = true
#   JULIA_DEPOT_PATH = /home/github/.julia:/home/github/actions-runner-1/_work/_tool/julia/1.11.4/x64/local/share/julia:/home/github/actions-runner-1/_work/_tool/julia/1.11.4/x64/share/julia
#   JULIA_LOAD_PATH = @:@v#.#:@stdlib

# %%
using Pkg
Pkg.status()
# Out:
# Project CaMKIIModel v0.6.0
# Status `~/actions-runner-1/_work/camkii-cardiomyocyte-model/camkii-cardiomyocyte-model/Project.toml`
#   [336ed68f] CSV v0.10.15
#   [a93c6f00] DataFrames v1.7.0
#   [459566f4] DiffEqCallbacks v4.3.0
#   [23fbe1c1] Latexify v0.16.6
#   [2fda8390] LsqFit v0.15.0
#   [961ee093] ModelingToolkit v9.65.0
#   [77ba4419] NaNMath v1.1.2
#   [1dea7af3] OrdinaryDiffEq v6.92.0
#   [91a5bcdd] Plots v1.40.9
#   [0bca4576] SciMLBase v2.75.1
#   [9672c7b4] SteadyStateDiffEq v2.4.1

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
